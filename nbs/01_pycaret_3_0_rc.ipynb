# %% [markdown]
# ## Example notebook
# Modified from https://pycaret.gitbook.io/docs / https://colab.research.google.com/drive/1_H0sHYhzKGZDmgzrQLosuZAR3nOaL6CN?usp=sharing

# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0

# %%
from pycaret.classification import *
s = setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_ff8d5_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff8d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff8d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ff8d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff8d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff8d5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ff8d5_row0_col1" class="data row0 col1" >2190</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff8d5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ff8d5_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff8d5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ff8d5_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff8d5_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_ff8d5_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff8d5_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ff8d5_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff8d5_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ff8d5_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff8d5_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ff8d5_row6_col1" class="data row6 col1" >(748, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff8d5_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ff8d5_row7_col1" class="data row7 col1" >(322, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff8d5_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_ff8d5_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff8d5_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_ff8d5_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ff8d5_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_ff8d5_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ff8d5_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_ff8d5_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ff8d5_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_ff8d5_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ff8d5_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_ff8d5_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ff8d5_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_ff8d5_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ff8d5_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_ff8d5_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ff8d5_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_ff8d5_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ff8d5_row17_col0" class="data row17 col0" >Low variance threshold</td>
#       <td id="T_ff8d5_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ff8d5_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_ff8d5_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ff8d5_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_ff8d5_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ff8d5_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_ff8d5_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ff8d5_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_ff8d5_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ff8d5_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_ff8d5_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ff8d5_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_ff8d5_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ff8d5_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_ff8d5_row24_col1" class="data row24 col1" >6313</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_1e8af th {
#   text-align: left;
# }
# #T_1e8af_row0_col0, #T_1e8af_row0_col2, #T_1e8af_row0_col3, #T_1e8af_row0_col4, #T_1e8af_row0_col5, #T_1e8af_row0_col6, #T_1e8af_row0_col7, #T_1e8af_row1_col0, #T_1e8af_row1_col4, #T_1e8af_row2_col0, #T_1e8af_row2_col1, #T_1e8af_row2_col2, #T_1e8af_row2_col3, #T_1e8af_row2_col5, #T_1e8af_row2_col6, #T_1e8af_row2_col7, #T_1e8af_row3_col0, #T_1e8af_row3_col1, #T_1e8af_row3_col2, #T_1e8af_row3_col3, #T_1e8af_row3_col4, #T_1e8af_row3_col5, #T_1e8af_row3_col6, #T_1e8af_row3_col7, #T_1e8af_row4_col0, #T_1e8af_row4_col1, #T_1e8af_row4_col2, #T_1e8af_row4_col3, #T_1e8af_row4_col4, #T_1e8af_row4_col5, #T_1e8af_row4_col6, #T_1e8af_row4_col7, #T_1e8af_row5_col0, #T_1e8af_row5_col1, #T_1e8af_row5_col2, #T_1e8af_row5_col3, #T_1e8af_row5_col4, #T_1e8af_row5_col5, #T_1e8af_row5_col6, #T_1e8af_row5_col7, #T_1e8af_row6_col0, #T_1e8af_row6_col1, #T_1e8af_row6_col2, #T_1e8af_row6_col3, #T_1e8af_row6_col4, #T_1e8af_row6_col5, #T_1e8af_row6_col6, #T_1e8af_row6_col7, #T_1e8af_row7_col0, #T_1e8af_row7_col1, #T_1e8af_row7_col2, #T_1e8af_row7_col3, #T_1e8af_row7_col4, #T_1e8af_row7_col5, #T_1e8af_row7_col6, #T_1e8af_row7_col7, #T_1e8af_row8_col0, #T_1e8af_row8_col1, #T_1e8af_row8_col2, #T_1e8af_row8_col3, #T_1e8af_row8_col4, #T_1e8af_row8_col5, #T_1e8af_row8_col6, #T_1e8af_row8_col7, #T_1e8af_row9_col0, #T_1e8af_row9_col1, #T_1e8af_row9_col2, #T_1e8af_row9_col3, #T_1e8af_row9_col4, #T_1e8af_row9_col5, #T_1e8af_row9_col6, #T_1e8af_row9_col7, #T_1e8af_row10_col0, #T_1e8af_row10_col1, #T_1e8af_row10_col2, #T_1e8af_row10_col3, #T_1e8af_row10_col4, #T_1e8af_row10_col5, #T_1e8af_row10_col6, #T_1e8af_row10_col7, #T_1e8af_row11_col0, #T_1e8af_row11_col1, #T_1e8af_row11_col2, #T_1e8af_row11_col3, #T_1e8af_row11_col4, #T_1e8af_row11_col5, #T_1e8af_row11_col6, #T_1e8af_row11_col7, #T_1e8af_row12_col0, #T_1e8af_row12_col1, #T_1e8af_row12_col2, #T_1e8af_row12_col3, #T_1e8af_row12_col4, #T_1e8af_row12_col5, #T_1e8af_row12_col6, #T_1e8af_row12_col7, #T_1e8af_row13_col0, #T_1e8af_row13_col1, #T_1e8af_row13_col2, #T_1e8af_row13_col3, #T_1e8af_row13_col4, #T_1e8af_row13_col5, #T_1e8af_row13_col6, #T_1e8af_row13_col7 {
#   text-align: left;
# }
# #T_1e8af_row0_col1, #T_1e8af_row1_col1, #T_1e8af_row1_col2, #T_1e8af_row1_col3, #T_1e8af_row1_col5, #T_1e8af_row1_col6, #T_1e8af_row1_col7, #T_1e8af_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1e8af_row0_col8, #T_1e8af_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_1e8af_row1_col8, #T_1e8af_row2_col8, #T_1e8af_row3_col8, #T_1e8af_row4_col8, #T_1e8af_row5_col8, #T_1e8af_row6_col8, #T_1e8af_row7_col8, #T_1e8af_row8_col8, #T_1e8af_row9_col8, #T_1e8af_row10_col8, #T_1e8af_row11_col8, #T_1e8af_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1e8af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e8af_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1e8af_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1e8af_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1e8af_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1e8af_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1e8af_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1e8af_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1e8af_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1e8af_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e8af_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_1e8af_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_1e8af_row0_col1" class="data row0 col1" >0.8342</td>
#       <td id="T_1e8af_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_1e8af_row0_col3" class="data row0 col3" >0.7908</td>
#       <td id="T_1e8af_row0_col4" class="data row0 col4" >0.7883</td>
#       <td id="T_1e8af_row0_col5" class="data row0 col5" >0.7882</td>
#       <td id="T_1e8af_row0_col6" class="data row0 col6" >0.6521</td>
#       <td id="T_1e8af_row0_col7" class="data row0 col7" >0.6536</td>
#       <td id="T_1e8af_row0_col8" class="data row0 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_1e8af_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_1e8af_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_1e8af_row1_col1" class="data row1 col1" >0.8342</td>
#       <td id="T_1e8af_row1_col2" class="data row1 col2" >0.9075</td>
#       <td id="T_1e8af_row1_col3" class="data row1 col3" >0.7944</td>
#       <td id="T_1e8af_row1_col4" class="data row1 col4" >0.7855</td>
#       <td id="T_1e8af_row1_col5" class="data row1 col5" >0.7889</td>
#       <td id="T_1e8af_row1_col6" class="data row1 col6" >0.6526</td>
#       <td id="T_1e8af_row1_col7" class="data row1 col7" >0.6537</td>
#       <td id="T_1e8af_row1_col8" class="data row1 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_1e8af_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_1e8af_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_1e8af_row2_col1" class="data row2 col1" >0.8315</td>
#       <td id="T_1e8af_row2_col2" class="data row2 col2" >0.9068</td>
#       <td id="T_1e8af_row2_col3" class="data row2 col3" >0.7637</td>
#       <td id="T_1e8af_row2_col4" class="data row2 col4" >0.7989</td>
#       <td id="T_1e8af_row2_col5" class="data row2 col5" >0.7799</td>
#       <td id="T_1e8af_row2_col6" class="data row2 col6" >0.6437</td>
#       <td id="T_1e8af_row2_col7" class="data row2 col7" >0.6452</td>
#       <td id="T_1e8af_row2_col8" class="data row2 col8" >0.4510</td>
#     </tr>
#     <tr>
#       <th id="T_1e8af_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_1e8af_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_1e8af_row3_col1" class="data row3 col1" >0.8303</td>
#       <td id="T_1e8af_row3_col2" class="data row3 col2" >0.8870</td>
#       <td id="T_1e8af_row3_col3" class="data row3 col3" >0.7734</td>
#       <td id="T_1e8af_row3_col4" class="data row3 col4" >0.7886</td>
#       <td id="T_1e8af_row3_col5" class="data row3 col5" >0.7802</td>
#       <td id="T_1e8af_row3_col6" class="data row3 col6" >0.6420</td>
#       <td id="T_1e8af_row3_col7" class="data row3 col7" >0.6429</td>
#       <td id="T_1e8af_row3_col8" class="data row3 col8" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_1e8af_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_1e8af_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1e8af_row4_col1" class="data row4 col1" >0.8275</td>
#       <td id="T_1e8af_row4_col2" class="data row4 col2" >0.9025</td>
#       <td id="T_1e8af_row4_col3" class="data row4 col3" >0.7771</td>
#       <td id="T_1e8af_row4_col4" class="data row4 col4" >0.7817</td>
#       <td id="T_1e8af_row4_col5" class="data row4 col5" >0.7785</td>
#       <td id="T_1e8af_row4_col6" class="data row4 col6" >0.6374</td>
#       <td id="T_1e8af_row4_col7" class="data row4 col7" >0.6384</td>
#       <td id="T_1e8af_row4_col8" class="data row4 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_1e8af_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_1e8af_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1e8af_row5_col1" class="data row5 col1" >0.8062</td>
#       <td id="T_1e8af_row5_col2" class="data row5 col2" >0.8835</td>
#       <td id="T_1e8af_row5_col3" class="data row5 col3" >0.7601</td>
#       <td id="T_1e8af_row5_col4" class="data row5 col4" >0.7526</td>
#       <td id="T_1e8af_row5_col5" class="data row5 col5" >0.7542</td>
#       <td id="T_1e8af_row5_col6" class="data row5 col6" >0.5946</td>
#       <td id="T_1e8af_row5_col7" class="data row5 col7" >0.5968</td>

# %%
# plot_model(best)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.classification import ClassificationExperiment
exp1 = ClassificationExperiment()

# %%
exp1.setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_e3311_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3311">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3311_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e3311_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3311_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3311_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e3311_row0_col1" class="data row0 col1" >8608</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3311_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e3311_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3311_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e3311_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3311_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_e3311_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3311_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e3311_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3311_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e3311_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3311_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e3311_row6_col1" class="data row6 col1" >(748, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3311_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e3311_row7_col1" class="data row7 col1" >(322, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3311_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_e3311_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3311_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_e3311_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e3311_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_e3311_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e3311_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_e3311_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e3311_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_e3311_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e3311_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_e3311_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e3311_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_e3311_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e3311_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_e3311_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e3311_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_e3311_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e3311_row17_col0" class="data row17 col0" >Low variance threshold</td>
#       <td id="T_e3311_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e3311_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_e3311_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e3311_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_e3311_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e3311_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_e3311_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e3311_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_e3311_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e3311_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_e3311_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e3311_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_e3311_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e3311_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e3311_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_e3311_row24_col1" class="data row24 col1" >8b07</td>
#     </tr>
#   </tbody>
# </table>

# %%
dir(exp1)
# Out:
# ['USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_ClassificationExperiment__is_multiclass',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_custom_pipeline',
#  '_all_metrics',
#  '_all_models',
#  '_all_models_internal',
#  '_available_plots',
#  '_balance',
#  '_bin_numerical_features',
#  '_calculate_metrics',
#  '_check_environment',
#  '_check_setup_ran',
#  '_choose_better',
#  '_convert_log_experiment',
#  '_create_app_predict_kwargs',
#  '_create_model',
#  '_create_model_with_cv',
#  '_create_model_without_cv',
#  '_date_feature_engineering',
#  '_encode_target_column',
#  '_encoding',
#  '_feature_selection',
#  '_fxs',
#  '_get_cv_n_folds',
#  '_get_cv_splitter',
#  '_get_default_plots_to_log',
#  '_get_final_model_from_pipeline',
#  '_get_greater_is_worse_columns',
#  '_get_groups',
#  '_get_metric_by_name_or_id',
#  '_get_metrics',
#  '_get_model_id',
#  '_get_model_name',
#  '_get_models',
#  '_get_return_train_score_columns_for_display',
#  '_get_return_train_score_indices_for_logging',
#  '_get_setup_display',
#  '_gpu_n_jobs_param',
#  '_group_features',
#  '_highlight_and_round_model_results',
#  '_highlight_models',
#  '_initialize_setup',
#  '_is_multiclass',
#  '_is_unsupervised',
#  '_iterative_imputation',
#  '_log_model',
#  '_low_variance',
#  '_ml_usecase',
#  '_normalization',
#  '_pack_for_remote',
#  '_parallel_compare_models',
#  '_pca',
#  '_plot_model',
#  '_polynomial_features',
#  '_prepare_column_types',
#  '_prepare_dataset',
#  '_prepare_folds',
#  '_prepare_train_test',
#  '_process_sort',
#  '_profile',
#  '_register_setup_params',
#  '_remote',
#  '_remove_multicollinearity',
#  '_remove_outliers',
#  '_set_all_metrics',
#  '_set_all_models',
#  '_set_engine',
#  '_set_exp_model_engines',
#  '_set_up_logging',
#  '_setup_params',
#  '_setup_ran',
#  '_simple_imputation',
#  '_target_transformation',
#  '_text_embedding',
#  '_transformation',
#  '_unpack_at_remote',
#  '_validate_log_experiment',
#  'add_metric',
#  'all_allowed_engines',
#  'automl',
#  'blend_models',
#  'calibrate_model',
#  'check_fairness',
#  'compare_models',
#  'convert_model',
#  'create_api',
#  'create_app',
#  'create_docker',
#  'create_model',
#  'dashboard',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'deep_check',
#  'deploy_model',
#  'display_container',
#  'eda',
#  'ensemble_model',
#  'evaluate_model',
#  'exp_id',
#  'exp_model_engines',
#  'exp_name_log',
#  'finalize_model',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'get_allowed_engines',
#  'get_config',
#  'get_engine',
#  'get_leaderboard',
#  'get_logs',
#  'get_metrics',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'interpret_model',
#  'load_config',
#  'load_model',
#  'log_plots_param',
#  'logger',
#  'logging_param',
#  'master_model_container',
#  'memory',
#  'models',
#  'n_jobs_param',
#  'optimize_threshold',
#  'pipeline',
#  'plot_model',
#  'plot_model_check_display_format_',
#  'predict_model',
#  'pull',
#  'remove_metric',
#  'save_config',
#  'save_model',
#  'seed',
#  'set_config',
#  'setup',
#  'stack_models',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'transform_target_param',
#  'tune_model',
#  'variable_keys',
#  'variables',
#  'verbose',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed']

# %%
exp1.compare_models()
# Out:
# <style type="text/css">
# #T_69d2c th {
#   text-align: left;
# }
# #T_69d2c_row0_col0, #T_69d2c_row0_col2, #T_69d2c_row0_col3, #T_69d2c_row0_col4, #T_69d2c_row1_col0, #T_69d2c_row1_col1, #T_69d2c_row1_col2, #T_69d2c_row1_col3, #T_69d2c_row1_col4, #T_69d2c_row1_col5, #T_69d2c_row1_col6, #T_69d2c_row1_col7, #T_69d2c_row2_col0, #T_69d2c_row2_col1, #T_69d2c_row2_col2, #T_69d2c_row2_col3, #T_69d2c_row2_col5, #T_69d2c_row2_col6, #T_69d2c_row2_col7, #